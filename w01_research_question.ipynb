# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikramkhan-gif1/FlyRank-ML-Internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ikramkhan-gif1/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane is Applied Search Intelligence. I want to explore how machine learning can help improve search ranking and understand which features influence whether a result is useful for users. I chose this lane because search systems are widely used in real products, and improving ranking decisions can help users find better information faster.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here
# breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# My work improves the decision of how search results should be ranked and which results should appear more useful to users. Search engineers and product teams can use these insights to improve ranking systems. A wrong recommendation could reduce user satisfaction by showing irrelevant results, causing users to spend more time finding information or leaving the platform.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/Ikramkhan-gif1/FlyRank-ML-Internship.git
# Out:
# fatal: destination path 'FlyRank-ML-Internship' already exists and is not an empty directory.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The dataset contains 30,000 content examples with 44 features. The data includes search-related signals such as search volume, competition, click-through rate (CTR), average position, and engagement rate. These measurements provide enough information to explore how machine learning can support search ranking decisions.

# %%
import pandas as pd

file_path = "FlyRank-ML-Internship/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(file_path)

print("Number of rows and columns:", df.shape)
print(df.head())
# Out:
# Number of rows and columns: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will provide observed and directional insights about search content performance and ranking factors. It can support decision-making by helping identify patterns and prioritize improvements. It will not claim causal proof that one factor directly causes higher rankings, and it will not claim to predict Google's search algorithm or future search results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
